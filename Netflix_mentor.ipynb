# %% [markdown]
# # Netflix Data: Cleaning, Analysis and Visualization

# %% [markdown]
# **about dataset**

# %% [markdown]
# Netflix is a popular streaming service that offers a vast catalog of movies, TV shows,
#  and original contents. This dataset is a cleaned version of the original version which
#  can be found here. The data consist of contents added to Netflix from 2008 to 2021.
#  The oldest content is as old as 1925 and the newest as 2021. This dataset will be
#  cleaned with pithon and visualized. The purpose of this dataset is to
#  test my data cleaning and visualization skills.

# %% [markdown]
# # 1 ) Import Required liabraries

# %%
import numpy as pn 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # 2 ) Load Dataset

# %%
data = pd.read_csv(r'E:\Project\Alma pro\Netflix_uni\netflix.csv')
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %% [markdown]
# # 3 ) Data Cleaning

# %%
# get top 5 rows from data 
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
# get bottom 5 rows from data 
data.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
# dealing with null values 
data.isnull().sum()

# treating with null values using dropna or filna
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
# dealing with duplicate 
data.drop_duplicates()
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
# shape of data 
row_col = data.shape
print('number of row :' , row_col[0])
print('number of columns :', row_col[-1])
# Out:
# number of row : 8790
# number of columns : 10

# %%
# get info about data 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
# convert date_added to date format 
data['date_added'] = pd.to_datetime(data['date_added'])
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# dtype: object

# %% [markdown]
# # 4 )  Exploratory Data Analysis

# %%
# count number of movie and tv show 
type_count = data['type'].value_counts()
type_count
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
# Distribution of content by type using  bar \ pie plot 
fig, axes = plt.subplots(1,2,figsize = (8,4))
sns.countplot (data = data,  x = data['type'] , ax = axes[0] , palette = 'Set2')
plt.pie(type_count , labels = ['Movie' , 'Tv Show'], autopct = '%0.f%%' )
plt.suptitle('Total Content on Netflix' , fontsize = 20 )
# plt.title('Distribution of content by Type')
# plt.ylabel('Number of Count')
plt.show()
# Out:
# C:\Users\faijal\AppData\Local\Temp\ipykernel_31284\753473731.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot (data = data,  x = data['type'] , ax = axes[0] , palette = 'Set2')

# %%
# most common Genres
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States 2021-09-25          2020  PG-13    90 min
# 1         France 2021-09-24          2021  TV-MA  1 Season
# 2  United States 2021-09-24          2021  TV-MA  1 Season
# 3         Brazil 2021-09-22          2021  TV-PG    91 min
# 4  United States 2021-09-24          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
# create new column genres
data['genres'] = data['listed_in'].apply(lambda x : x.split(','))

# %%
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States 2021-09-25          2020  PG-13    90 min
# 1         France 2021-09-24          2021  TV-MA  1 Season
# 2  United States 2021-09-24          2021  TV-MA  1 Season
# 3         Brazil 2021-09-22          2021  TV-PG    91 min
# 4  United States 2021-09-24          1993  TV-MA   125 min
#
#                                            listed_in  \
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
all_genres = sum(data['genres'], [])
genre_count = pd.Series(all_genres).value_counts().head(10)
top_10 = genre_count.nlargest(10)
bottom_10 = genre_count.nsmallest(10)
print('top 10 \n' , top_10)
print('Bottom 10 \n', bottom_10)
# Out:
# top 10
#   International Movies     2624
# Dramas                    1599
# Comedies                  1210
# Action & Adventure         859
# Documentaries              829
#  Dramas                    827
# International TV Shows     773
#  Independent Movies        736
#  TV Dramas                 695
#  Romantic Movies           613
# Name: count, dtype: int64
# Bottom 10
#   Romantic Movies           613
#  TV Dramas                 695
#  Independent Movies        736
# International TV Shows     773
#  Dramas                    827
# Documentaries              829
# Action & Adventure         859
# Comedies                  1210
# Dramas                    1599
#  International Movies     2624
# Name: count, dtype: int64

# %%
plt.figure( figsize = (9,4))
sns.barplot(x = genre_count.index , y = genre_count.values )
plt.title('Most common Genress in Netflix')
plt.ylabel('Number of counts')
plt.xlabel('Genre type')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'genre', 'genres'],
#       dtype='object')

# %%
# Rating count on netflix
rating_count = data['rating'].value_counts().reset_index().sort_values(by = 'count' , ascending = False)
rating_count
# Out:
#       rating  count
# 0      TV-MA   3205
# 1      TV-14   2157
# 2      TV-PG    861
# 3          R    799
# 4      PG-13    490
# 5      TV-Y7    333
# 6       TV-Y    306
# 7         PG    287
# 8       TV-G    220
# 9         NR     79
# 10         G     41
# 11  TV-Y7-FV      6
# 12     NC-17      3
# 13        UR      3

# %%
# rating count on Netflix using bar 
plt.figure ( figsize = (8,4))
plt.bar(rating_count['rating']  , rating_count['count'])
plt.xticks(rotation=45, ha='right')
plt.xlabel("Rating Types")
plt.ylabel("Rating Frequency")
plt.suptitle('Rating on Netflix', fontsize=20)
plt.show()

# %%
# bar for rating on Netflix
plt.pie(  rating_count['count'][:8] ,labels =rating_count['rating'][:8], autopct = '%0.0f%%')
plt.suptitle('Rating on Netflix' , fontsize = 20)
plt.show()

# %%
# based on country 
data['country'].value_counts()
# Out:
# country
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
#                   ...
# Iran                 1
# West Germany         1
# Greece               1
# Zimbabwe             1
# Soviet Union         1
# Name: count, Length: 86, dtype: int64

# %%
top_country = data['country'].value_counts().reset_index().sort_values (by ='count', ascending = False)[:10]
top_country
# Out:
#           country  count
# 0   United States   3240
# 1           India   1057
# 2  United Kingdom    638
# 3        Pakistan    421
# 4       Not Given    287
# 5          Canada    271
# 6           Japan    259
# 7     South Korea    214
# 8          France    213
# 9           Spain    182

# %%
# top 10 countries base on content on netflix
plt.figure ( figsize = (10,5))
plt.bar(top_country['country'] , top_country['count'])
plt.xticks(rotation = 45 , ha ='right')
plt.suptitle('Top 10 countries base on content on Netflix' , fontsize = 15)
plt.xlabel ('Country Name')
plt.ylabel('Number of Count')
plt.show()

# %%
# MonthlyreleasesofMoviesandTVshowson Netflix
data['Month'] = data.date_added.dt.month
data['Month'].unique()
# Out:
# array([ 9,  5,  7,  6, 11,  8,  4,  3,  2,  1, 12, 10])

# %%
monthly_movie_release = data[data['type'] == 'Movie']['Month'].value_counts().sort_index()
monthly_Tvshow_release = data[data['type'] == 'TV Show']['Month'].value_counts().sort_index()
# Out:
# array([545, 382, 528, 549, 439, 492, 565, 518, 518, 545, 498, 547],
#       dtype=int64)

# %%
# MonthlyreleasesofMoviesandTVshowson Netflix
plt.figure(figsize=(8,4))
plt.plot(monthly_movie_release.index , monthly_movie_release.values , label = 'Movie')
plt.plot(monthly_Tvshow_release.index , monthly_Tvshow_release.values , label = 'Tv Show')
plt.ylabel('Frequency of Release')
plt.xlabel('Month')
plt.legend()
plt.grid(True)
plt.xticks(range(1,13) , ['JAN', 'FEB','MAR','APR','MAY','JUN','JULY','AUG','SEP','OCT','NOV','DEC'])
plt.suptitle('Monthly releases of Movies and TVshowson Netflix' , fontsize = 17)
plt.show()

# %%
# yearly  releases of Movies and TVshowson Netflix
data['add_year'] = data['date_added'].dt.year
movie_year = data[data['type'] == 'Movie']['add_year'].value_counts().sort_index(ascending = False)
Tv_show_year = data[data['type'] == 'TV Show']['add_year'].value_counts().sort_index(ascending = False)

# %%
# yearly  releases of Movies and TVshows on Netflix
plt.figure(figsize = (8,4))
plt.plot(movie_year.index ,movie_year.values , label = 'Movie') 
plt.plot(Tv_show_year.index , Tv_show_year.values , label = 'Tv show')
plt.xlabel('Year')
plt.ylabel('Frequency of releasese')
plt.grid(True)
plt.legend()
plt.suptitle('yearly  releases of Movies and TV shows on Netflix' , fontsize = 17)
plt.show()

# %%
# Top 10 popular genres for movies on Netflix
movie_genres = data[data['type'] =='Movie'].groupby('listed_in').size().sort_values(ascending = False)[:10]
plt.figure(figsize = (10,5))
plt.bar(movie_genres.index , movie_genres.values )
plt.xticks(rotation = 45 , ha = 'right')
plt.xlabel('Genre')
plt.ylabel('Movie Frequency')
plt.suptitle('Top 10 popular genres for movies on Netflix' , fontsize = 17)
plt.show()

# %%
# Top 10 popular genres for Tv show on Netflix
tvshow_genres = data[data['type'] =='TV Show'].groupby('listed_in').size().sort_values(ascending = False)[:10]
plt.figure(figsize = (10,5))
plt.bar(tvshow_genres.index , tvshow_genres.values )
plt.xticks(rotation = 45 , ha = 'right')
plt.xlabel('Genre')
plt.ylabel('Tv Show Frequency')
plt.suptitle('Top 10 popular genres for Tv Show on Netflix' , fontsize = 17)
plt.show()

# %%
# Top 15 directors across Netflix with hoigh frequency of movies and Tv shows
top_directors = data['director'].value_counts().reset_index().sort_values(by = 'count', ascending = False)[1:16]
top_directors
# Out:
#                         director  count
# 1                  Rajiv Chilaka     20
# 2            Alastair Fothergill     18
# 3         Raúl Campos, Jan Suter     18
# 4                    Suhas Kadav     16
# 5                   Marcus Raboy     16
# 6                      Jay Karas     14
# 7            Cathy Garcia-Molina     13
# 9                Youssef Chahine     12
# 10                   Jay Chapman     12
# 8                Martin Scorsese     12
# 11              Steven Spielberg     11
# 12  Mark Thornton, Todd Kauffman     10
# 13              Don Michael Paul     10
# 14                  David Dhawan      9
# 20               Shannon Hartman      8

# %%
plt.figure(figsize = (10,5))
plt.bar(top_directors['director'] , top_directors['count'])
plt.xticks(rotation = 45, ha ='right')
plt.xlabel('Director')
plt.ylabel('Frequency of movie and Tv show')
plt.suptitle('Top 15 directors across Netflix with hoigh frequency of movies and Tv shows', fontsize = 15)
plt.show()

# %% [markdown]
# #  Conclusion and Insights

# %% [raw]
#  1 ) 70 % movie  and 30 % tv show content added on netflix
#  2 ) TV_MA is highest rating it's cover 38 % of total rating
#  3 ) in US country most content addes on Netflix
#  4 ) after 2014 movie contnet added on netflix is higher than tv show
#  5 ) top genres movie on netfliix is drama , international movies  , documentrorys and top genree on  tv show is kid's tv
#  6 ) top director based on movie and tv show is Rajiv shilaka , alastair , etc
